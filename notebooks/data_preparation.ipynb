# %%
# %load_ext kedro.ipython
# Out:
# [03/28/25 13:59:14] INFO     Using                                                                  ]8;id=239366;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=782062;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'D:\devtools\venv-pos-ia\Lib\site-packages\kedro\framework\project\ric
#                              h_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=213929;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=230462;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=912922;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=321556;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py#65\65]8;;\
#                     INFO     Resolved project path as: D:\devtools\infnet.                          ]8;id=604857;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=720560;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py#180\180]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/28/25 13:59:16] WARNING  D:\devtools\venv-pos-ia\Lib\site-packages\mlflow\pyfunc\utils\data_val ]8;id=529165;file://C:\Python311\Lib\warnings.py\warnings.py]8;;\:]8;id=882683;file://C:\Python311\Lib\warnings.py#110\110]8;;\
#                              idation.py:168: UserWarning: [33mAdd type hints to the `predict`
#                              method to enable data validation and automatic signature inference
#                              during model logging. Check
#                              https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage
#                              -in-pythonmodel for more details.[0m
#                                color_warning(
#                     INFO     Registering new custom resolver: 'km.random_name'                    ]8;id=20905;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py\mlflow_hook.py]8;;\:]8;id=466340;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py#65\65]8;;\
#                     WARNING  No 'mlflow.yml' config file found in environment. Default            ]8;id=193381;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py\mlflow_hook.py]8;;\:]8;id=299552;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_mlflow\framework\hooks\mlflow_hook.py#78\78]8;;\
#                              configuration will be used. Use ``kedro mlflow init`` command in CLI
#                              to customize the configuration.
#                     INFO     The 'tracking_uri' key in mlflow.yml is relative            ]8;id=647345;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_mlflow\config\kedro_mlflow_config.py\kedro_mlflow_config.py]8;;\:]8;id=193606;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_mlflow\config\kedro_mlflow_config.py#293\293]8;;\
#                              ('server.mlflow_(tracking|registry)_uri = mlruns'). It is
#                              converted to a valid uri:
#                              'file:///D:/devtools/infnet/mlruns'
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=897570;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=650359;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [03/28/25 13:59:17] INFO     Kedro project infnet                                                   ]8;id=664513;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=364487;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=530894;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=124378;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\ipython\__init__.py#147\147]8;;\
#                              'pipelines'

# %%
df_dev = catalog.load("dataset_kobe_dev")
# Out:
# [03/28/25 13:59:24] INFO     Loading data from dataset_kobe_dev (ParquetDataset)...             ]8;id=838150;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=550150;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#390\390]8;;\

# %%
df_dev.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          action_type combined_shot_type  game_event_id   game_id      lat  \
# 0          Jump Shot          Jump Shot             10  20000012  33.9723
# 1          Jump Shot          Jump Shot             12  20000012  34.0443
# 2          Jump Shot          Jump Shot             35  20000012  33.9093
# 3          Jump Shot          Jump Shot             43  20000012  33.8693
# 4  Driving Dunk Shot               Dunk            155  20000012  34.0443
#
#    loc_x  loc_y       lon  minutes_remaining  period  ...       shot_type  \
# 0    167     72 -118.1028                 10       1  ...  2PT Field Goal
# 1   -157      0 -118.4268                 10       1  ...  2PT Field Goal
# 2   -101    135 -118.3708                  7       1  ...  2PT Field Goal
# 3    138    175 -118.1318                  6       1  ...  2PT Field Goal
# 4      0      0 -118.2698                  6       2  ...  2PT Field Goal
#
#           shot_zone_area  shot_zone_basic  shot_zone_range     team_id  \
# 0          Right Side(R)        Mid-Range        16-24 ft.  1610612747
# 1           Left Side(L)        Mid-Range         8-16 ft.  1610612747
# 2   Left Side Center(LC)        Mid-Range        16-24 ft.  1610612747
# 3  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612747
# 4              Center(C)  Restricted Area  Less Than 8 ft.  1610612747
#
#             team_name   game_date    matchup opponent  shot_id
# 0  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        1
# 1  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        2
# 2  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        3
# 3  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        4
# 4  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        5
#
# [5 rows x 25 columns]

# %%
print(1)
# Out:
# 1

# %%
import mlflow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Selecionar colunas
columns_to_keep = ["lat", "lon", "minutes_remaining", "period", "playoffs", "shot_distance", "shot_made_flag"]
df = df_dev[columns_to_keep]

# %%
# Remover linhas com valores faltantes
df = df.dropna()
df.head(10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 1   34.0443 -118.4268                 10       1         0             15
# 2   33.9093 -118.3708                  7       1         0             16
# 3   33.8693 -118.1318                  6       1         0             22
# 4   34.0443 -118.2698                  6       2         0              0
# 5   34.0553 -118.4148                  9       3         0             14
# 6   34.0443 -118.2698                  8       3         0              0
# 8   33.9363 -118.3348                  6       3         0             12
# 9   33.9193 -118.3028                  3       3         0             12
# 11  33.9173 -118.1488                 11       1         0             17
# 12  33.9343 -118.3368                  7       1         0             12
#
#     shot_made_flag
# 1              0.0
# 2              1.0
# 3              0.0
# 4              1.0
# 5              0.0
# 6              1.0
# 8              1.0
# 9              0.0
# 11             1.0
# 12             1.0

# %%
scaler = StandardScaler()
df[["lat", "lon", "minutes_remaining", "period", "playoffs", "shot_distance"]] = scaler.fit_transform(
    df[["lat", "lon", "minutes_remaining", "period", "playoffs", "shot_distance"]]
)
df.head(10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          lat       lon  minutes_remaining    period  playoffs  shot_distance  \
# 1   0.966036 -1.761147           1.431116 -1.282025 -0.417991       0.632816
# 2  -1.082742 -1.161570           0.554892 -1.282025 -0.417991       0.765102
# 3  -1.689787  1.397338           0.262817 -1.282025 -0.417991       1.558820
# 4   0.966036 -0.080190           0.262817 -0.411069 -0.417991      -1.351479
# 5   1.132974 -1.632666           1.139041  0.459887 -0.417991       0.500529
# 6   0.966036 -0.080190           0.846966  0.459887 -0.417991      -1.351479
# 8  -0.672986 -0.776128           0.262817  0.459887 -0.417991       0.235957
# 9  -0.930981 -0.433513          -0.613407  0.459887 -0.417991       0.235957
# 11 -0.961333  1.215324           1.723190 -1.282025 -0.417991       0.897388
# 12 -0.703339 -0.797541           0.554892 -1.282025 -0.417991       0.235957
#
#     shot_made_flag
# 1              0.0
# 2              1.0
# 3              0.0
# 4              1.0
# 5              0.0
# 6              1.0
# 8              1.0
# 9              0.0
# 11             1.0
# 12             1.0

# %%
# Dimensão do dataset após limpeza
print("Dimensão do dataset após limpeza: ",df.shape)
# Out:
# Dimensão do dataset após limpeza:  (20285, 7)

# %%
catalog.save("data_filtered", df)
# Out:
# [03/28/25 13:43:17] INFO     Saving data to data_filtered (ParquetDataset)...                   ]8;id=672900;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=799786;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#432\432]8;;\

# %%
# Separação treino e teste (estratificada)
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df["shot_made_flag"], random_state=42)

# %%
# Tamanhos das bases
print("Tamanho da base de treino: ",train_df.shape[0])
# Out:
# Tamanho da base de treino:  16228

# %%
print("Tamanho da base de teste: ",test_df.shape[0])
# Out:
# Tamanho da base de teste:  4057

# %%
catalog.save("base_train", train_df)
catalog.save("base_test", test_df)
# Out:
# [03/28/25 13:43:29] INFO     Saving data to base_train (ParquetDataset)...                      ]8;id=792839;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=629385;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#432\432]8;;\
#                     INFO     Saving data to base_test (ParquetDataset)...                       ]8;id=640597;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=705434;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#432\432]8;;\

# %%
from pycaret.classification import *

# %%
import pycaret
import joblib
print("PyCaret Version:", pycaret.__version__)
print("Joblib Version:", joblib.__version__)
# Out:
# PyCaret Version: 3.3.2
# Joblib Version: 1.3.2

# %%
train = catalog.load('base_train')
session_id = catalog.load('params:session_id')
# Out:
# [03/28/25 13:59:52] INFO     Loading data from base_train (ParquetDataset)...                   ]8;id=232323;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=488868;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#390\390]8;;\
#                     INFO     Loading data from params:session_id (MemoryDataset)...             ]8;id=63484;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=682204;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#390\390]8;;\

# %%
exp = ClassificationExperiment()
exp.setup(data=train, target='shot_made_flag', session_id=session_id, experiment_name='pd_pycaret')
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# <pandas.io.formats.style.Styler object at 0x000001709A59D490>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pycaret.classification.oop.ClassificationExperiment object at 0x000001709A47C390>

# %%
exp.get_metrics()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc          <function accuracy_score at 0x000001709182CB80>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa      <function cohen_kappa_score at 0x000001709182C...
# mcc        <function matthews_corrcoef at 0x000001709182D...
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# auc        make_scorer(roc_auc_score, response_method=('d...  pred_proba
# recall     make_scorer(recall_score, response_method='pre...        pred
# precision  make_scorer(precision_score, response_method='...        pred
# f1         make_scorer(f1_score, response_method='predict...        pred
# kappa      make_scorer(cohen_kappa_score, response_method...        pred
# mcc        make_scorer(matthews_corrcoef, response_method...        pred
#
#                                                     Args  Greater is Better  \
# ID
# acc                                                   {}               True
# auc        {'average': 'weighted', 'multi_class': 'ovr'}               True
# recall                           {'average': 'weighted'}               True
# precision                        {'average': 'weighted'}               True
# f1                               {'average': 'weighted'}               True
# kappa                                                 {}               True
# mcc                                                   {}               True
#
#            Multiclass  Custom
# ID
# acc              True   False
# auc              True   False
# recall           True   False
# precision        True   False
# f1               True   False
# kappa            True   False
# mcc              True   False

# %%
exp.compare_models()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <pandas.io.formats.style.Styler object at 0x0000017098994990>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# <pandas.io.formats.style.Styler object at 0x00000170989946D0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
# <pandas.io.formats.style.Styler object at 0x00000170990414D0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .           Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
# <pandas.io.formats.style.Styler object at 0x00000170989F9B10>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
# <pandas.io.formats.style.Styler object at 0x0000017098AE6650>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
# <pandas.io.formats.style.Styler object at 0x0000017098BE73D0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .           Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:05:33
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# <pandas.io.formats.style.Styler object at 0x0000017096B9C310>
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                    Fitting 10 Folds
# Estimator  Quadratic Discriminant Analysis
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                 Selecting Estimator
# Estimator  Quadratic Discriminant Analysis
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                 Selecting Estimator
# Estimator  Quadratic Discriminant Analysis
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                     Initializing CV
# Estimator  Quadratic Discriminant Analysis
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                    Fitting 10 Folds
# Estimator  Quadratic Discriminant Analysis
# <pandas.io.formats.style.Styler object at 0x0000017098B02190>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:05:33
# Status     . . . . . . . . . . . . . . . . . .      Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ada Boost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:05:33
# Status     . . . . . . . . . . . . . . . . . .   Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Ada Boost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:05:33
# Status     . . . . . . . . . . . . . . . . . .   Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Ada Boost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:05:33
# Status     . . . . . . . . . . . . . . . . . .       Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ada Boost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:05:33
# Status     . . . . . . . . . . . . . . . . . .      Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ada Boost Classifier
# <pandas.io.formats.style.Styler object at 0x0000017098AE6850>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .               Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# <pandas.io.formats.style.Styler object at 0x0000017098BE7E50>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Discriminant Analysis
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Discriminant Analysis
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .           Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Discriminant Analysis
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .               Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Discriminant Analysis
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:05:33
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Discriminant Analysis
# <pandas.io.formats.style.Styler object at 0x0000017098B3A310>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Classifier
# <pandas.io.formats.style.Styler object at 0x0000017096BA5F10>
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                 Selecting Estimator
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                     Initializing CV
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:05:33
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <pandas.io.formats.style.Styler object at 0x0000017098997CD0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
# <pandas.io.formats.style.Styler object at 0x0000017096D86290>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Dummy Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Dummy Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Dummy Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Dummy Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Dummy Classifier
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <pandas.io.formats.style.Styler object at 0x00000170964B60D0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .        Dummy Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:05:33
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .    Ada Boost Classifier
# <IPython.core.display.HTML object>
# <IPython.core.display.HTML object>
# <pandas.io.formats.style.Styler object at 0x00000170964B60D0>
# AdaBoostClassifier(algorithm='SAMME.R', estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=54321)

# %%
train_df = catalog.load('base_train')
test_df = catalog.load('base_test')
# Out:
# [03/28/25 14:09:55] INFO     Loading data from base_train (ParquetDataset)...                   ]8;id=751090;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=764021;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#390\390]8;;\
#                     INFO     Loading data from base_test (ParquetDataset)...                    ]8;id=962982;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=200172;file://D:\devtools\venv-pos-ia\Lib\site-packages\kedro\io\data_catalog.py#390\390]8;;\

# %%
# Registrar no MLflow
mlflow.set_experiment("PreparacaoDados")
# Out:
# 2025/03/28 14:10:49 INFO mlflow.tracking.fluent: Experiment with name 'PreparacaoDados' does not exist. Creating a new experiment.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Experiment: artifact_location='file:///D:/devtools/infnet/mlruns/817716148887471761', creation_time=1743181849035, experiment_id='817716148887471761', last_update_time=1743181849035, lifecycle_stage='active', name='PreparacaoDados', tags={}>

# %%
# Tamanhos das bases
train_size = train_df.shape[0]
test_size = test_df.shape[0]

with mlflow.start_run(run_name="PreparacaoDados"):
    mlflow.log_param("test_size", 0.2)
    mlflow.log_metric("train_size", train_size)
    mlflow.log_metric("test_size", test_size)

# %%
# Obter o último experimento registrado
experiment = mlflow.get_experiment_by_name("PreparacaoDados")
runs = mlflow.search_runs(experiment.experiment_id)

# Mostrar as últimas execuções
print(runs[["run_id", "metrics.train_size", "metrics.test_size", "params.test_size"]])
# Out:
#                              run_id  metrics.train_size  metrics.test_size  \
# 0  24d5dcf88bd34ac7acb0ba7b6d3ec8c3             16228.0             4057.0
#
#   params.test_size
# 0              0.2
